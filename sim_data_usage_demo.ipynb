# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import display
import optoanalysis

# %%
ConvFactor = 1.8e5

# %%
dat = optoanalysis.sim_data.SimData([0, 1e-2], 5e6, [75e3, 160e3, 180e3], 4000.0, 3.1e-19, ConvFactor, 1e-30,  dt=0.5e-9)
# Out:
# solving...
# solving...
# solving...
# /home/ash/anaconda2/envs/python3/lib/python3.5/site-packages/scipy/signal/spectral.py:772: UserWarning: nperseg = 1000000, is greater than input length = 50000, using nperseg = 50000
#   'using nperseg = {1:d}'.format(nperseg, x.shape[-1]))

# %%
# tArray = dat.sde_solvers[0].tArray.get_array()

# fig,ax = plt.subplots()
# ax.plot(tArray, dat.sde_solvers[0].q)
# ax.plot(tArray, dat.sde_solvers[1].q)
# ax.plot(tArray, dat.sde_solvers[2].q)

# %%
fig, ax = dat.plot_PSD([0, 300])

# %%
dat.extract_ZXY_motion?

# %%
z, x, y, t, fig, ax = dat.extract_ZXY_motion([75e3, 160e3, 180e3], 3e3, [10e3, 5e3, 5e3], subSampleFraction=2)
# Out:
# filtering Z
# filtering X
# filtering Y
# /home/ash/anaconda2/envs/python3/lib/python3.5/site-packages/scipy/signal/spectral.py:772: UserWarning: nperseg = 1000000, is greater than input length = 25000, using nperseg = 25000
#   'using nperseg = {1:d}'.format(nperseg, x.shape[-1]))

# %%
t, z, vz = dat.calc_phase_space(75e3, ConvFactor, FractionOfSampleFreq=2)
t, x, vx = dat.calc_phase_space(160e3, ConvFactor, FractionOfSampleFreq=2)
t, y, vy = dat.calc_phase_space(180e3, ConvFactor, FractionOfSampleFreq=2)
# Out:
# filtering data
# filtering data
# filtering data

# %%
TimeTuple = [500e-6, 1000e-6]
alpha=0.8

# %%
plt.plot(t, z*1e9, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[0, 0]*1e9, alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t[1:], vz, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[0, 1], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t, x*1e9, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[1, 0]*1e9, alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t[1:], vx, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[1, 1], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t, y*1e9, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[2, 0]*1e9, alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
plt.plot(t[1:], vy, alpha=alpha)
plt.plot(dat.simtime.get_array(), dat.TrueSignals[2, 1], alpha=alpha)
plt.xlim(TimeTuple)
# Out:
# (0.0005, 0.001)

# %%
dat.get_fit_auto(75e3)
# Out:
# /home/ash/anaconda2/envs/python3/lib/python3.5/site-packages/optoanalysis-3.3.4-py3.5-linux-x86_64.egg/optoanalysis/optoanalysis.py:510: UserWarning: range is too small to fit, returning NaN
#   _warnings.warn("range is too small to fit, returning NaN", UserWarning)
# found best
# A: 3580098852739.3047 +- 18.718114581329424%
# Trap Frequency: 470548.16144295817 +- 0.17600087051479324%
# Big Gamma: 4274.847560977478 +- 38.75821479146928%
# (470548.16144295817+/-828.168860330961,
#  3580098852739.3047+/-670127005380.6031,
#  4274.847560977478+/-1656.8545996915366,
#  <matplotlib.figure.Figure at 0x7f043d48e198>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f043cc58208>)
